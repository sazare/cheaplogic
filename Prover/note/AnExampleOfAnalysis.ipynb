# %% [markdown]
# # A example: analyzing proofs

# %%
cd("..")

# %%
# set base of the repository
include("loadall.jl")
# Out:
# ... cheaplogic is loaded

# %%
ch=readcore("data/his001.cnf")
# Out:
# readcore fname=data/his001.cnf
# CORE("data/his001.cnf", [8], [0], Dict{Any,Any}(:L10=>LForm2(:L10, :(+(P(a, b)))),:L2=>LForm2(:L2, :(-(P(x_C2, y_C2)))),:L11=>LForm2(:L11, :(+(P(b, c)))),:L1=>LForm2(:L1, :(+(P(e, f)))),:L4=>LForm2(:L4, :(-(A(c, Y)))),:L5=>LForm2(:L5, :(+(P(c, d)))),:L8=>LForm2(:L8, :(-(P(y_C3, z_C3)))),:L6=>LForm2(:L6, :(+(P(d, e)))),:L9=>LForm2(:L9, :(+(A(x_C3, z_C3)))),:L3=>LForm2(:L3, :(+(A(x_C2, y_C2))))…), Dict{Any,Any}(:C8=>VForm2(:C8, Any[]),:C2=>VForm2(:C2, Symbol[:x_C2, :y_C2]),:C1=>VForm2(:C1, Symbol[:Y]),:C6=>VForm2(:C6, Any[]),:C7=>VForm2(:C7, Any[]),:C3=>VForm2(:C3, Symbol[:x_C3, :y_C3, :z_C3]),:C4=>VForm2(:C4, Any[]),:C5=>VForm2(:C5, Any[])), Dict{Any,Any}(:C8=>Any[:L1],:C2=>Any[:L2, :L3],:C1=>Any[:L4],:C6=>Any[:L5],:C7=>Any[:L6],:C3=>Any[:L7, :L8, :L9],:C4=>Any[:L10],:C5=>Any[:L11]), Dict{Any,Any}(:L10=>:C4,:L2=>:C2,:L11=>:C5,:L1=>:C8,:L4=>:C1,:L5=>:C6,:L8=>:C3,:L6=>:C7,:L9=>:C3,:L3=>:C2…), Any[:A, :P], Dict{Any,Any}(), Dict{Any,Any}(), Any[], [0], [0])

# %%
printclauses(ch)
# Out:
# C1:[Y]. L4.-(A(c, Y))
# C2:[x_C2,y_C2]. L2.-(P(x_C2, y_C2)), L3.+(A(x_C2, y_C2))
# C3:[x_C3,y_C3,z_C3]. L7.-(A(x_C3, y_C3)), L8.-(P(y_C3, z_C3)), L9.+(A(x_C3, z_C3))
# C4:[]. L10.+(P(a, b))
# C5:[]. L11.+(P(b, c))
# C6:[]. L5.+(P(c, d))
# C7:[]. L6.+(P(d, e))
# C8:[]. L1.+(P(e, f))

# %%
printcore(ch)
# Out:
# name = data/his001.cnf
# max cid = [8]
# max rid = [0]
# Proc
#
# CDB
# C8: VForm2(:C8, Any[])
# C2: VForm2(:C2, Symbol[:x_C2, :y_C2])
# C1: VForm2(:C1, Symbol[:Y])
# C6: VForm2(:C6, Any[])
# C7: VForm2(:C7, Any[])
# C3: VForm2(:C3, Symbol[:x_C3, :y_C3, :z_C3])
# C4: VForm2(:C4, Any[])
# C5: VForm2(:C5, Any[])
#
# LDB
# L10: +(P(a, b))
# L2: -(P(x_C2, y_C2))
# L11: +(P(b, c))
# L1: +(P(e, f))
# L4: -(A(c, Y))
# L5: +(P(c, d))
# L8: -(P(y_C3, z_C3))
# L6: +(P(d, e))
# L9: +(A(x_C3, z_C3))
# L3: +(A(x_C2, y_C2))
# L7: -(A(x_C3, y_C3))
#
# LCMAP
# L10=>C4
# L2=>C2
# L11=>C5
# L1=>C8
# L4=>C1
# L5=>C6
# L8=>C3
# L6=>C7
# L9=>C3
# L3=>C2
# L7=>C3
#
# CLMAP
# C8=>Any[:L1]
# C2=>Any[:L2, :L3]
# C1=>Any[:L4]
# C6=>Any[:L5]
# C7=>Any[:L6]
# C3=>Any[:L7, :L8, :L9]
# C4=>Any[:L10]
# C5=>Any[:L11]
#
# TEMPLATE(level0)
#
# PROOFS
#
# -- end of core --
#
# MEASURE
# #trial   = 0
# #success = 0

# %% [markdown]
# ## Static analysis

# %%
# initial pairs
cch, mch=pairmakefromcore(ch)
printpvms(mch, cch)
# Out:
# ---
#  <L9:+(A(x_C3, z_C3)); L4:-(A(c, Y))>
# x_C3/c,z_C3/Y
# ---
# *<L9:+(A(x_C3, z_C3)); L7:-(A(x_C3, y_C3))>
# z_C3/y_C3,z_C3/y_C3
# ---
#  <L3:+(A(x_C2, y_C2)); L4:-(A(c, Y))>
# x_C2/c,y_C2/Y
# ---
#  <L3:+(A(x_C2, y_C2)); L7:-(A(x_C3, y_C3))>
# x_C2/x_C3,y_C2/y_C3
# ---
#  <L10:+(P(a, b)); L2:-(P(x_C2, y_C2))>
# x_C2/a,y_C2/b
# ---
#  <L10:+(P(a, b)); L8:-(P(y_C3, z_C3))>
# y_C3/a,z_C3/b
# ---
#  <L11:+(P(b, c)); L2:-(P(x_C2, y_C2))>
# x_C2/b,y_C2/c
# ---
#  <L11:+(P(b, c)); L8:-(P(y_C3, z_C3))>
# y_C3/b,z_C3/c
# ---
#  <L1:+(P(e, f)); L2:-(P(x_C2, y_C2))>
# x_C2/e,y_C2/f
# ---
#  <L1:+(P(e, f)); L8:-(P(y_C3, z_C3))>
# y_C3/e,z_C3/f
# ---
#  <L5:+(P(c, d)); L2:-(P(x_C2, y_C2))>
# x_C2/c,y_C2/d
# ---
#  <L5:+(P(c, d)); L8:-(P(y_C3, z_C3))>
# y_C3/c,z_C3/d
# ---
#  <L6:+(P(d, e)); L2:-(P(x_C2, y_C2))>
# x_C2/d,y_C2/e
# ---
#  <L6:+(P(d, e)); L8:-(P(y_C3, z_C3))>
# y_C3/d,z_C3/e

# %%
# proving1 and dynamic analysis
rhis001,chis001=simpleprover("data/his001.cnf",10,15)
# Out:
# readcore fname=data/his001.cnf
# Array{Any,1}[[:L4]] => Any[Any[:L7_R1, :L8_R1], Any[:L2_R2]]
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# Any[Any[:L7_R1, :L8_R1], Any[:L2_R2]] => Any[Any[:L8_R3, :L7_R3, :L8_R3], Any[:L8_R4, :L2_R4], Any[]]
# Any[Any[:L8_R3, :L7_R3, :L8_R3], Any[:L8_R4, :L2_R4], Any[]] => Any[Any[:L7_R6], Any[:L7_R7], Any[:L7_R8], Any[:L7_R9], Any[:L7_R10], Any[:L2_R11], Any[:L2_R12], Any[:L2_R13], Any[:L2_R14], Any[:L2_R15]]
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# Any[Any[:L7_R6], Any[:L7_R7], Any[:L7_R8], Any[:L7_R9], Any[:L7_R10], Any[:L2_R11], Any[:L2_R12], Any[:L2_R13], Any[:L2_R14], Any[:L2_R15]] => Any[Any[:L7_R16, :L8_R16], Any[:L2_R17], Any[:L7_R18, :L8_R18], Any[:L2_R19], Any[:L7_R20, :L8_R20], Any[:L2_R21], Any[:L7_R22, :L8_R22], Any[:L2_R23], Any[:L7_R24, :L8_R24], Any[:L2_R25], Any[]]
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# Any[Any[:L7_R16, :L8_R16], Any[:L2_R17], Any[:L7_R18, :L8_R18], Any[:L2_R19], Any[:L7_R20, :L8_R20], Any[:L2_R21], Any[:L7_R22, :L8_R22], Any[:L2_R23], Any[:L7_R24, :L8_R24], Any[:L2_R25], Any[]] => Any[Any[:L8_R27, :L7_R27, :L8_R27], Any[:L8_R28, :L2_R28], Any[:L8_R29, :L7_R29, :L8_R29], Any[:L8_R30, :L2_R30], Any[:L8_R31, :L7_R31, :L8_R31], Any[:L8_R32, :L2_R32], Any[:L8_R33, :L7_R33, :L8_R33], Any[:L8_R34, :L2_R34], Any[:L8_R35, :L7_R35, :L8_R35], Any[:L8_R36, :L2_R36], Any[]]
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# Any[Any[:L8_R27, :L7_R27, :L8_R27], Any[:L8_R28, :L2_R28], Any[:L8_R29, :L7_R29, :L8_R29], Any[:L8_R30, :L2_R30], Any[:L8_R31, :L7_R31, :L8_R31], Any[:L8_R32, :L2_R32], Any[:L8_R33, :L7_R33, :L8_R33], Any[:L8_R34, :L2_R34], Any[:L8_R35, :L7_R35, :L8_R35], Any[:L8_R36, :L2_R36], Any[]] => Any[Any[:L7_R38], Any[:L7_R39], Any[:L7_R40], Any[:L7_R41], Any[:L7_R42], Any[:L8_R43], Any[:L7_R44], Any[:L7_R45], Any[:L7_R46], Any[:L7_R47], Any[:L7_R48], Any[:L2_R49], Any[:L7_R50], Any[:L7_R51], Any[:L7_R52], Any[:L7_R53], Any[:L7_R54], Any[:L2_R55], Any[:L7_R56], Any[:L7_R57], Any[:L7_R58], Any[:L7_R59], Any[:L7_R60], Any[:L2_R61], Any[:L7_R62], Any[:L7_R63], Any[:L7_R64], Any[:L7_R65], Any[:L7_R66], Any[:L2_R67]]
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :a, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
R109], Any[:L2_R110], Any[:L7_R111, :L8_R111], Any[:L2_R112], Any[:L7_R113, :L8_R113], Any[:L2_R114], Any[:L7_R115, :L8_R115], Any[:L2_R116], Any[:L7_R117, :L8_R117], Any[:L2_R118]] => Any[Any[:L8_R119, :L7_R119, :L8_R119], Any[:L8_R120, :L2_R120], Any[:L8_R121, :L7_R121, :L8_R121], Any[:L8_R122, :L2_R122], Any[:L8_R123, :L7_R123, :L8_R123], Any[:L8_R124, :L2_R124], Any[:L8_R125, :L7_R125, :L8_R125], Any[:L8_R126, :L2_R126], Any[:L8_R127, :L7_R127, :L8_R127], Any[:L8_R128, :L2_R128], Any[], Any[:L8_R130, :L7_R130, :L8_R130], Any[:L8_R131, :L2_R131], Any[:L8_R132, :L7_R132, :L8_R132], Any[:L8_R133, :L2_R133], Any[:L8_R134, :L7_R134, :L8_R134], Any[:L8_R135, :L2_R135], Any[:L8_R136, :L7_R136, :L8_R136], Any[:L8_R137, :L2_R137], Any[:L8_R138, :L7_R138, :L8_R138], Any[:L8_R139, :L2_R139], Any[], Any[:L8_R141, :L7_R141, :L8_R141], Any[:L8_R142, :L2_R142], Any[:L8_R143, :L7_R143, :L8_R143], Any[:L8_R144, :L2_R144], Any[:L8_R145, :L7_R145, :L8_R145], Any[:L8_R146, :L2_R146], Any[:L8_R147, :L7_R147, :L8_R147], Any[:L8_R148, :L2_R148], Any[:L8_R149, :L7_R149, :L8_R149], Any[:L8_R150, :L2_R150], Any[], Any[:L8_R152, :L7_R152, :L8_R152], Any[:L8_R153, :L2_R153], Any[:L8_R154, :L7_R154, :L8_R154], Any[:L8_R155, :L2_R155], Any[:L8_R156, :L7_R156, :L8_R156], Any[:L8_R157, :L2_R157], Any[:L8_R158, :L7_R158, :L8_R158], Any[:L8_R159, :L2_R159], Any[:L8_R160, :L7_R160, :L8_R160], Any[:L8_R161, :L2_R161], Any[], Any[:L8_R163, :L7_R163, :L8_R163], Any[:L8_R164, :L2_R164], Any[:L8_R165, :L7_R165, :L8_R165], Any[:L8_R166, :L2_R166], Any[:L8_R167, :L7_R167, :L8_R167], Any[:L8_R168, :L2_R168], Any[:L8_R169, :L7_R169, :L8_R169], Any[:L8_R170, :L2_R170], Any[:L8_R171, :L7_R171, :L8_R171], Any[:L8_R172, :L2_R172], Any[]]
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# FAIL = ICMP(:b, :c, :unify0ss)
# FAIL = ICMP(:b, :e, :unify0ss)
# FAIL = ICMP(:b, :d, :unify0ss)
# FAIL = ICMP(:b, :f, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :f, :unify0ss)
# FAIL = ICMP(:a, :c, :unify0ss)
# FAIL = ICMP(:a, :e, :unify0ss)
# FAIL = ICMP(:a, :d, :unify0ss)
# FAIL = ICMP(:a, :b, :unify0ss)
# FAIL = ICMP(:a, :f, :unify0ss)
# FAIL = ICMP(:c, :b, :unify0ss)
# FAIL = ICMP(:c, :d, :unify0ss)
# FAIL = ICMP(:c, :a, :unify0ss)
# FAIL = ICMP(:c, :e, :unify0ss)
# FAIL = ICMP(:e, :c, :unify0ss)
# FAIL = ICMP(:e, :d, :unify0ss)
# FAIL = ICMP(:e, :b, :unify0ss)
# FAIL = ICMP(:e, :f, :unify0ss)
# FAIL = ICMP(:d, :c, :unify0ss)
# FAIL = ICMP(:d, :e, :unify0ss)
# FAIL = ICMP(:d, :b, :unify0ss)
# FAIL = ICMP(:d, :f, :unify0ss)
# Any[Any[:L8_R119, :L7_R119, :L8_R119], Any[:L8_R120, :L2_R120], Any[:L8_R121, :L7_R121, :L8_R121], Any[:L8_R122, :L2_R122], Any[:L8_R123, :L7_R123, :L8_R123], Any[:L8_R124, :L2_R124], Any[:L8_R125, :L7_R125, :L8_R125], Any[:L8_R126, :L2_R126], Any[:L8_R127, :L7_R127, :L8_R127], Any[:L8_R128, :L2_R128], Any[], Any[:L8_R130, :L7_R130, :L8_R130], Any[:L8_R131, :L2_R131], Any[:L8_R132, :L7_R132, :L8_R132], Any[:L8_R133, :L2_R133
[]),:R334=>VForm2(:R334, Symbol[:y_C3R334]),:R390=>VForm2(:R390, Any[]),:R296=>VForm2(:R296, Any[])…), Dict{Any,Any}(:R13=>Any[:L2_R13],:R145=>Any[:L8_R145, :L7_R145, :L8_R145],:R175=>Any[:L7_R175],:R243=>Any[:L7_R243],:R25=>Any[:L2_R25],:R196=>Any[:L7_R196],:R220=>Any[:L7_R220],:R334=>Any[:L7_R334, :L8_R334],:R390=>Any[:L2_R390],:R296=>Any[:L7_R296]…), Dict{Any,Any}(:L7_R31=>:R31,:L8_R31=>:R31,:L8_R536=>:R536,:L2_R299=>:R299,:L7_R86=>:R86,:L7_R432=>:R432,:L7_R328=>:R328,:L2_R343=>:R343,:L7_R352=>:R352,:L7_R94=>:R94…), Any[:A, :P], Dict{Any,Any}(Symbol("-P")=>Any[Any[:C6, Any[], :L5, Any[]], Any[:C7, Any[], :L6, Any[]], Any[:C4, Any[], :L10, Any[]], Any[:C8, Any[], :L1, Any[]], Any[:C5, Any[], :L11, Any[]]],Symbol("+P")=>Any[Any[:C2, Symbol[:x_C2, :y_C2], :L2, Any[:L3]], Any[:C3, Symbol[:x_C3, :y_C3, :z_C3], :L8, Any[:L7, :L9]]],Symbol("-A")=>Any[Any[:C3, Symbol[:x_C3, :y_C3, :z_C3], :L9, Any[:L7, :L8]], Any[:C2, Symbol[:x_C2, :y_C2], :L3, Any[:L2]]],Symbol("+A")=>Any[Any[:C1, Symbol[:Y], :L4, Any[]], Any[:C3, Symbol[:x_C3, :y_C3, :z_C3], :L7, Any[:L8, :L9]]]), Dict{Any,Any}(:R13=>STEP(:R13, :L8_R4, :L1, Symbol[:e, :f], Array{Any,1}[[], []]),:R145=>STEP(:R145, :L7_R92, :L9, Symbol[:z_C3, :c, :y_C3, :z_C3], Array{Any,1}[[:z_C3, :y_C3], [:z_C3R145, :y_C3R145]]),:R175=>STEP(:R175, :L8_R119, :L6, Symbol[:e, :d], Array{Any,1}[[], []]),:R243=>STEP(:R243, :L8_R143, :L10, Symbol[:b, :a], Array{Any,1}[[], []]),:R25=>STEP(:R25, :L7_R10, :L3, Symbol[:c, :d], Array{Any,1}[[], []]),:R196=>STEP(:R196, :L8_R125, :L1, Symbol[:f, :e], Array{Any,1}[[], []]),:R220=>STEP(:R220, :L8_R134, :L1, Symbol[:f, :e], Array{Any,1}[[], []]),:R334=>STEP(:R334, :L7_R180, :L9, Symbol[:c, :y_C3, :b], Array{Any,1}[[:y_C3], [:y_C3R334]]),:R390=>STEP(:R390, :L7_R212, :L3, Symbol[:c, :c], Array{Any,1}[[], []]),:R296=>STEP(:R296, :L8_R163, :L5, Symbol[:d, :c], Array{Any,1}[[], []])…), Any[], [1044], [578]))

# %%
# prop level proofs
printproofs0(chis001)
# Out:
# R1=<C1:C3>
# R3=<R1:C3>
# R6=<R3:C4>
# R16=<R6:C3>
# R27=<R16:C3>
# R42=<R27:C7>
# R77=<R42:C2>
# R129=<R77:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R7=<R3:C5>
# R18=<R7:C3>
# R29=<R18:C3>
# R48=<R29:C7>
# R87=<R48:C2>
# R140=<R87:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R8=<R3:C8>
# R20=<R8:C3>
# R31=<R20:C3>
# R54=<R31:C7>
# R97=<R54:C2>
# R151=<R97:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R9=<R3:C6>
# R22=<R9:C3>
# R33=<R22:C3>
# R60=<R33:C7>
# R108=<R60:C2>
# R162=<R108:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R10=<R3:C7>
# R24=<R10:C3>
# R35=<R24:C3>
# R66=<R35:C7>
# R118=<R66:C2>
# R173=<R118:C6>
#
# ---
# R1=<C1:C3>
# R4=<R1:C2>
# R15=<R4:C7>
# R26=<R15:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R6=<R3:C4>
# R16=<R6:C3>
# R27=<R16:C3>
# R41=<R27:C8>
# R74=<R41:C3>
# R126=<R74:C2>
# R197=<R126:C7>
# R364=<R197:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R10=<R3:C7>
# R25=<R10:C2>
# R37=<R25:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R7=<R3:C5>
# R18=<R7:C3>
# R29=<R18:C3>
# R47=<R29:C8>
# R84=<R47:C3>
# R137=<R84:C2>
# R227=<R137:C7>
# R415=<R227:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R8=<R3:C8>
# R20=<R8:C3>
# R31=<R20:C3>
# R53=<R31:C8>
# R94=<R53:C3>
# R148=<R94:C2>
# R257=<R148:C7>
# R466=<R257:C6>
#
# ---
# R2=<C1:C2>
# R5=<R2:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R9=<R3:C6>
# R22=<R9:C3>
# R33=<R22:C3>
# R59=<R33:C8>
# R105=<R59:C3>
# R159=<R105:C2>
# R287=<R159:C7>
# R517=<R287:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R10=<R3:C7>
# R24=<R10:C3>
# R35=<R24:C3>
# R65=<R35:C8>
# R115=<R65:C3>
# R170=<R115:C2>
# R317=<R170:C7>
# R568=<R317:C6>
#
# ---
# R1=<C1:C3>
# R3=<R1:C3>
# R8=<R3:C8>
# R20=<R8:C3>
# R32=<R20:C2>
# R55=<R32:C7>
# R98=<R55:C6>
#
# ---

# %%
# R45 is contradiction from the proofs or
contradictionsof(chis001)
# Out:
# 14-element Array{Any,1}:
#  :R129
#  :R466
#  :R415
#  :R5
#  :R98
#  :R364
#  :R173
#  :R568
#  :R140
#  :R26
#  :R162
#  :R517
#  :R37
#  :R151

# %%
printclause(:R45, chis001)
# Out:
# R45:[]. L7_R45.-(A(c, c))

# %%
# show informations in the all proofs
printmgus(chis001)
# Out:
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R6:<L8_R3:L10>=z/b;y/a;
# R16:<L7_R6:L9>=x/c;z/a;
# R27:<L7_R16:L9>=y/z;x/c;
# R42:<L8_R27:L6>=z/e;y/d;
# R77:<L7_R42:L3>=x/c;y/d;
# R129:<L2_R77:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R8:<L8_R3:L1>=z/f;y/e;
# R20:<L7_R8:L9>=x/c;z/e;
# R31:<L7_R20:L9>=y/z;x/c;
# R53:<L8_R31:L1>=z/f;y/e;
# R94:<L7_R53:L9>=x/c;z/e;
# R148:<L7_R94:L3>=x/c;
# R257:<L8_R148:L6>=y/d;
# R466:<L2_R257:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R7:<L8_R3:L11>=z/c;y/b;
# R18:<L7_R7:L9>=x/c;z/b;
# R29:<L7_R18:L9>=y/z;x/c;
# R47:<L8_R29:L1>=z/f;y/e;
# R84:<L7_R47:L9>=x/c;z/e;
# R137:<L7_R84:L3>=x/c;
# R227:<L8_R137:L6>=y/d;
# R415:<L2_R227:L5>=
# ---
#
# R2:<L4:L3>=Y/y;x/c;
# R5:<L2_R2:L5>=y/d;
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R8:<L8_R3:L1>=z/f;y/e;
# R20:<L7_R8:L9>=x/c;z/e;
# R32:<L7_R20:L3>=x/c;
# R55:<L8_R32:L6>=y/d;
# R98:<L2_R55:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R6:<L8_R3:L10>=z/b;y/a;
# R16:<L7_R6:L9>=x/c;z/a;
# R27:<L7_R16:L9>=y/z;x/c;
# R41:<L8_R27:L1>=z/f;y/e;
# R74:<L7_R41:L9>=x/c;z/e;
# R126:<L7_R74:L3>=x/c;
# R197:<L8_R126:L6>=y/d;
# R364:<L2_R197:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R10:<L8_R3:L6>=z/e;y/d;
# R24:<L7_R10:L9>=x/c;z/d;
# R35:<L7_R24:L9>=y/z;x/c;
# R66:<L8_R35:L6>=z/e;y/d;
# R118:<L7_R66:L3>=x/c;y/d;
# R173:<L2_R118:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R10:<L8_R3:L6>=z/e;y/d;
# R24:<L7_R10:L9>=x/c;z/d;
# R35:<L7_R24:L9>=y/z;x/c;
# R65:<L8_R35:L1>=z/f;y/e;
# R115:<L7_R65:L9>=x/c;z/e;
# R170:<L7_R115:L3>=x/c;
# R317:<L8_R170:L6>=y/d;
# R568:<L2_R317:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R7:<L8_R3:L11>=z/c;y/b;
# R18:<L7_R7:L9>=x/c;z/b;
# R29:<L7_R18:L9>=y/z;x/c;
# R48:<L8_R29:L6>=z/e;y/d;
# R87:<L7_R48:L3>=x/c;y/d;
# R140:<L2_R87:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R4:<L7_R1:L3>=x/c;
# R15:<L8_R4:L6>=y/d;z/e;
# R26:<L2_R15:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R9:<L8_R3:L5>=z/d;y/c;
# R22:<L7_R9:L9>=x/c;z/c;
# R33:<L7_R22:L9>=y/z;x/c;
# R60:<L8_R33:L6>=z/e;y/d;
# R108:<L7_R60:L3>=x/c;y/d;
# R162:<L2_R108:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R9:<L8_R3:L5>=z/d;y/c;
# R22:<L7_R9:L9>=x/c;z/c;
# R33:<L7_R22:L9>=y/z;x/c;
# R59:<L8_R33:L1>=z/f;y/e;
# R105:<L7_R59:L9>=x/c;z/e;
# R159:<L7_R105:L3>=x/c;
# R287:<L8_R159:L6>=y/d;
# R517:<L2_R287:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R10:<L8_R3:L6>=z/e;y/d;
# R25:<L7_R10:L3>=x/c;y/d;
# R37:<L2_R25:L5>=
# ---
#
# R1:<L4:L9>=Y/z;x/c;
# R3:<L7_R1:L9>=y/z;x/c;
# R8:<L8_R3:L1>=z/f;y/e;
# R20:<L7_R8:L9>=x/c;z/e;
# R31:<L7_R20:L9>=y/z;x/c;
# R54:<L8_R31:L6>=z/e;y/d;
# R97:<L7_R54:L3>=x/c;y/d;
# R151:<L2_R97:L5>=
# ---

# %%
clause2of(:R97,chis001)
# Out:
# CForm2(:R97, Any[], Any[:(-(P(c, d)))])

# %%
inf = traceof(chis001); 0
# Out:
# 0

# %%
inf[1]
# Out:
# 1-element Array{Any,1}:
#  :Y

# %%
inf[2]
# Out:
# 14-element Array{Any,1}:
#  Any[:R129, Symbol[:z_C3R1R3]]
#  Any[:R466, Symbol[:z_C3R1R3]]
#  Any[:R415, Symbol[:z_C3R1R3]]
#  Any[:R5, Symbol[:d]]
#  Any[:R98, Symbol[:z_C3R1R3]]
#  Any[:R364, Symbol[:z_C3R1R3]]
#  Any[:R173, Symbol[:z_C3R1R3]]
#  Any[:R568, Symbol[:z_C3R1R3]]
#  Any[:R140, Symbol[:z_C3R1R3]]
#  Any[:R26, Symbol[:e]]
#  Any[:R162, Symbol[:z_C3R1R3]]
#  Any[:R517, Symbol[:z_C3R1R3]]
#  Any[:R37, Symbol[:z_C3R1R3]]
#  Any[:R151, Symbol[:z_C3R1R3]]

# %%
# in R104, Z captured a variable. Non complete info...

# %%
# show detail information of the proof of R45
printatrace1(:R45, varsof(:C1, chis001),chis001);println()
# Out:
# C1:[Y]. L4.-(A(c, Y))
#     VARS: (Y)
# C3:[x_C3,y_C3,z_C3]. L7.-(A(x_C3, y_C3)), L8.-(P(y_C3, z_C3)), L9.+(A(x_C3, z_C3))
#     VARS: (Y)
# ----
# <L4:L9>
#    unify:(Y,x_C3,y_C3,z_C3)←(z_C3,c,y_C3,z_C3)
#     VARS: (z_C3)
#    rename:(y_C3,z_C3)⇦(y_C3R1,z_C3R1)
#     VARS: (z_C3R1)
# R1:[y_C3R1,z_C3R1]. L7_R1.-(A(c, y_C3R1)), L8_R1.-(P(y_C3R1, z_C3R1))
# ----
#
#     VARS: (z_C3R1)
# C3:[x_C3,y_C3,z_C3]. L7.-(A(x_C3, y_C3)), L8.-(P(y_C3, z_C3)), L9.+(A(x_C3, z_C3))
#     VARS: (z_C3R1)
# ----
# <L7_R1:L9>
#    unify:(y_C3R1,z_C3R1,x_C3,y_C3,z_C3)←(z_C3,z_C3R1,c,y_C3,z_C3)
#     VARS: (z_C3R1)
#    rename:(z_C3,z_C3R1,y_C3)⇦(z_C3R3,z_C3R1R3,y_C3R3)
#     VARS: (z_C3R1R3)
# R3:[z_C3R3,z_C3R1R3,y_C3R3]. L8_R3.-(P(y_C3R3, z_C3R3)), L7_R3.-(A(c, y_C3R3)), L8_R3.-(P(y_C3R3, z_C3R3))
# ----
#
#     VARS: (z_C3R1R3)
# C5:[]. L11.+(P(b, c))
#     VARS: (z_C3R1R3)
# ----
# <L8_R3:L11>
#    unify:(z_C3R3,z_C3R1R3,y_C3R3)←(c,z_C3R1R3,b)
#     VARS: (z_C3R1R3)
#    rename:()⇦()
#     VARS: (z_C3R1R3)
# R7:[]. L7_R7.-(A(c, b))
# ----
#
#     VARS: (z_C3R1R3)
# C3:[x_C3,y_C3,z_C3]. L7.-(A(x_C3, y_C3)), L8.-(P(y_C3, z_C3)), L9.+(A(x_C3, z_C3))
#     VARS: (z_C3R1R3)
# ----
# <L7_R7:L9>
#    unify:(x_C3,y_C3,z_C3)←(c,y_C3,b)
#     VARS: (z_C3R1R3)
#    rename:(y_C3)⇦(y_C3R18)
#     VARS: (z_C3R1R3)
# R18:[y_C3R18]. L7_R18.-(A(c, y_C3R18)), L8_R18.-(P(y_C3R18, b))
# ----
#
#     VARS: (z_C3R1R3)
# C3:[x_C3,y_C3,z_C3]. L7.-(A(x_C3, y_C3)), L8.-(P(y_C3, z_C3)), L9.+(A(x_C3, z_C3))
#     VARS: (z_C3R1R3)
# ----
# <L7_R18:L9>
#    unify:(y_C3R18,x_C3,y_C3,z_C3)←(z_C3,c,y_C3,z_C3)
#     VARS: (z_C3R1R3)
#    rename:(z_C3,y_C3)⇦(z_C3R29,y_C3R29)
#     VARS: (z_C3R1R3)
# R29:[z_C3R29,y_C3R29]. L8_R29.-(P(y_C3R29, z_C3R29)), L7_R29.-(A(c, y_C3R29)), L8_R29.-(P(y_C3R29, z_C3R29))
# ----
#
#     VARS: (z_C3R1R3)
# C6:[]. L5.+(P(c, d))
#     VARS: (z_C3R1R3)
# ----
# <L8_R29:L5>
#    unify:(z_C3R29,y_C3R29)←(d,c)
#     VARS: (z_C3R1R3)
#    rename:()⇦()
#     VARS: (z_C3R1R3)
# R45:[]. L7_R45.-(A(c, c))
# ----
#
#     VARS: (z_C3R1R3)

# %% [markdown]
# ## ☕️
